# %% [markdown]
# # 🚀 Memory Management - Part 1 - Sessions
#
# **Welcome to Day 3 of the Kaggle 5-day Agents course!**
#
# In this notebook, you'll learn:
#
# - ✅ What sessions are and how to use them in your agent
# - ✅ How to build *stateful* agents with sessions and events
# - ✅ How to persist sessions in a database
# - ✅ Context management practices such as context compaction
# - ✅ Best practices for sharing session State

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### 1.3: Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %% [markdown]
# ### 1.4: Helper functions
#
# Helper function that manages a complete conversation session, handling session
# creation/retrieval, query processing, and response streaming. It supports
# both single queries and multiple queries in sequence.
#
# Example:
#
# ```
# >>> await run_session(runner, "What is the capital of France?", "geography-session")
# >>> await run_session(runner, ["Hello!", "What's my name?"], "user-intro-session")
# ```

# %%
# Define helper functions that will be reused throughout the notebook
async def run_session(
    runner_instance: Runner,
    user_queries: list[str] | str = None,
    session_name: str = "default",
):
    print(f"\n ### Session: {session_name}")

    # Get app name from the Runner
    app_name = runner_instance.app_name

    # Attempt to create a new session or retrieve an existing one
    try:
        session = await session_service.create_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )
    except:
        session = await session_service.get_session(
            app_name=app_name, user_id=USER_ID, session_id=session_name
        )

    # Process queries if provided
    if user_queries:
        # Convert single query to list for uniform processing
        if type(user_queries) == str:
            user_queries = [user_queries]

        # Process each query in the list sequentially
        for query in user_queries:
            print(f"\nUser > {query}")

            # Convert the query string to the ADK Content format
            query = types.Content(role="user", parts=[types.Part(text=query)])

            # Stream the agent's response asynchronously
            async for event in runner_instance.run_async(
                user_id=USER_ID, session_id=session.id, new_message=query
            ):
                # Check if the event contains valid content
                if event.content and event.content.parts:
                    # Filter out empty or "None" responses before printing
                    if (
                        event.content.parts[0].text != "None"
                        and event.content.parts[0].text
                    ):
                        print(f"{MODEL_NAME} > ", event.content.parts[0].text)
    else:
        print("No queries!")


print("✅ Helper functions defined.")
# Out:
# ✅ Helper functions defined.

# %% [markdown]
# ### 1.5: Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %% [markdown]
# ---
# ## 🤹 Section 2: Session Management
#
# ### 2.1 The Problem
#
# At their core, Large Language Models are **inherently stateless**. Their awareness is confined to the information you provide in a single API call. This means an agent without proper context management will react to the current prompt without considering any previous history.
#
# **❓ Why does this matter?** Imagine trying to have a meaningful conversation with someone who forgets everything you've said after each sentence. That's the challenge we face with raw LLMs!
#
# In ADK, we use `Sessions` for **short term memory management** and `Memory` for **long term memory.** In the next notebook, you'll focus on `Memory`.

# %% [markdown]
# ### 2.2 What is a Session?
#
# #### **📦 Session**
#
# A session is a container for conversations. It encapsulates the conversation history in a chronological manner and also records all tool interactions and responses for a **single, continuous conversation**. A session is tied to a user and agent; it is not shared with other users. Similarly, a session history for an Agent is not shared with other Agents.
#
# In ADK, a **Session** is comprised of two key components `Events` and `State`:
#
# **📝 Session.Events**:
#
# > While a session is a container for conversations, `Events` are the building blocks of a conversation.
# >
# > Example of Events:
# > - *User Input*: A message from the user (text, audio, image, etc.)
# > - *Agent Response*: The agent's reply to the user
# > - *Tool Call*: The agent's decision to use an external tool or API
# > - *Tool Output*: The data returned from a tool call, which the agent uses to continue its reasoning
#
#
# **{} Session.State**:
#
# > `session.state` is the Agent's scratchpad, where it stores and updates dynamic details needed during the conversation. Think of it as a global `{key, value}` pair storage which is available to all subagents and tools.

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/session-state-and-events.png" width="320" alt="Session state and events">
#
# <!-- ```mermaid
# graph TD
#     subgraph A["Agentic Application"];
#         subgraph U["User"]
#             subgraph S1["Session"]
#                 D1["Session.Events"]
#                 D2["Session.State"]
#             end
#         end
#     end
# ``` -->

# %% [markdown]
# ### 2.3 How to manage sessions?
#
# An agentic application can have multiple users and each user may have multiple sessions with the application.
# To manage these sessions and events, ADK offers a **Session Manager** and **Runner**.
#
# 1. **`SessionService`**: The storage layer
#    - Manages creation, storage, and retrieval of session data
#    - Different implementations for different needs (memory, database, cloud)
#
# 2. **`Runner`**: The orchestration layer
#    - Manages the flow of information between user and agent
#    - Automatically maintains conversation history
#    - Handles the Context Engineering behind the scenes
#
# Think of it like this:
#
# - **Session** = A notebook 📓
# - **Events** = Individual entries in a single page 📝
# - **SessionService** = The filing cabinet storing notebooks 🗄️
# - **Runner** = The assistant managing the conversation 🤖

# %% [markdown]
# ### 2.4 Implementing Our First Stateful Agent
#
# Let's build our first stateful agent, that can remember and have constructive conversations.
#
# ADK offers different types of sessions suitable for different needs. As a start, we'll start with a simple Session Management option (`InMemorySessionService`):

# %%
APP_NAME = "default"  # Application
USER_ID = "default"  # User
SESSION = "default"  # Session

MODEL_NAME = "gemini-2.5-flash-lite"


# Step 1: Create the LLM Agent
root_agent = Agent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot",  # Description of the agent's purpose
)

# Step 2: Set up Session Management
# InMemorySessionService stores conversations in RAM (temporary)
session_service = InMemorySessionService()

# Step 3: Create the Runner
runner = Runner(agent=root_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Stateful agent initialized!")
print(f"   - Application: {APP_NAME}")
print(f"   - User: {USER_ID}")
print(f"   - Using: {session_service.__class__.__name__}")
# Out:
# ✅ Stateful agent initialized!
#    - Application: default
#    - User: default
#    - Using: InMemorySessionService

# %% [markdown]
# ### 2.5 Testing Our Stateful Agent
#
# Now let's see the magic of sessions in action!

# %%
# Run a conversation with two queries in the same session
# Notice: Both queries are part of the SAME session, so context is maintained
await run_session(
    runner,
    [
        "Hi, I am Jeeya! What is the capital of United States?",
        "Hello! What is my name?",  # This time, the agent should remember!
    ],
    "stateful-agentic-session",
)
# Out:
#  ### Session: stateful-agentic-session
#
# User > Hi, I am Jeeya! What is the capital of United States?
# gemini-2.5-flash-lite >  Hi Jeeya! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Jeeya.

# %% [markdown]
# 🎉 **Success!** The agent remembered your name because both queries were part of the same session. The Runner automatically maintained the conversation history.
#
# But there's a catch: `InMemorySessionService` is temporary. **Once the application stops, all conversation history is lost.**

# %% [markdown]
# ### 🛑 (Optional) 2.6 Testing Agent's forgetfulness
#
# > To verify that the agent forgets the conversation, **restart the kernel**. Then, **run ALL the previous cells in this notebook EXCEPT the `run_session` in 2.5.**
# >
# > Now run the cell below. You'll see that the agent doesn't remember anything from the previous conversation.

# %%
# Run this cell after restarting the kernel. All this history will be gone...
await run_session(
    runner,
    ["What did I ask you about earlier?", "And remind me, what's my name?"],
    "stateful-agentic-session",
)  # Note, we are using same session name
# Out:
#  ### Session: stateful-agentic-session
#
# User > What did I ask you about earlier?
# gemini-2.5-flash-lite >  You asked me about the capital of the United States.
#
# User > And remind me, what's my name?
# gemini-2.5-flash-lite >  Your name is Jeeya.

# %% [markdown]
# ### The Problem
#
# Session information is not persistent (i.e., meaningful conversations are lost). While this is advantageous in testing environments, **in the real world, a user should be able to refer from past and resume conversations.** To achieve this, we must persist information.

# %% [markdown]
# ---
# ## 📈 Section 3: Persistent Sessions with `DatabaseSessionService`
#
# While `InMemorySessionService` is great for prototyping, real-world applications need conversations to survive restarts, crashes, and deployments. Let's level up to persistent storage!
#
# ### 3.1 Choosing the Right SessionService
#
# ADK provides different SessionService implementations for different needs:
#
# | Service | Use Case | Persistence | Best For |
# |---------|----------|-------------|----------|
# | **InMemorySessionService** | Development & Testing | ❌ Lost on restart | Quick prototypes |
# | **DatabaseSessionService** | Self-managed apps | ✅ Survives restarts | Small to medium apps |
# | **Agent Engine Sessions** | Production on GCP | ✅ Fully managed | Enterprise scale |

# %% [markdown]
# ### 3.2 Implementing Persistent Sessions
#
# Let's upgrade to `DatabaseSessionService` using SQLite. This gives us persistence without needing a separate database server for this demo.
#
# Let's create a `chatbot_agent` capable of having a conversation with the user.

# %%
# Step 1: Create the same agent (notice we use LlmAgent this time)
chatbot_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="A text chatbot with persistent memory",
)

# Step 2: Switch to DatabaseSessionService
# SQLite database will be created automatically
db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Step 3: Create a new runner with persistent storage
runner = Runner(agent=chatbot_agent, app_name=APP_NAME, session_service=session_service)

print("✅ Upgraded to persistent sessions!")
print(f"   - Database: my_agent_data.db")
print(f"   - Sessions will survive restarts!")
# Out:
# ✅ Upgraded to persistent sessions!
#    - Database: my_agent_data.db
#    - Sessions will survive restarts!

# %% [markdown]
# ### 3.3 Test Run 1: Verifying Persistence
#
# In this first test run, we'll start a new conversation with the session ID `test-db-session-01`. We will first introduce our name as 'Sam' and then ask a question. In the second turn, we will ask the agent for our name.
#
# Since we are using `DatabaseSessionService`, the agent should remember the name.
#
# After the conversation, we'll inspect the `my_agent_data.db` SQLite database directly to see how the conversation `events` (the user queries and model responses) are stored.

# %%
await run_session(
    runner,
    ["Hi, I am Jeeya! What is the capital of the United States?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > Hi, I am Jeeya! What is the capital of the United States?
# gemini-2.5-flash-lite >  Hi Jeeya! The capital of the United States is Washington, D.C.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Jeeya.

# %% [markdown]
# ### 🛑 (Optional) 3.4 Test Run 2: Resuming a Conversation
#
# > ‼️ Now, let's repeat the test again, but this time, **let's stop this Kaggle Notebook's kernel and restart it again.**
# >
# > 1. Run all the previous cells in the notebook, **EXCEPT** the previous Section 3.3 (`run_session` cell).
# >
# > 2. Now, run the below cell with the **same session ID** (`test-db-session-01`).
#
# We will ask a new question and then ask for our name again. **Because the session is loaded from the database, the agent should still remember** that our name is 'Sam' from the first test run. This demonstrates the power of persistent sessions.

# %%
await run_session(
    runner,
    ["What is the capital of India?", "Hello! What is my name?"],
    "test-db-session-01",
)
# Out:
#  ### Session: test-db-session-01
#
# User > What is the capital of India?
# gemini-2.5-flash-lite >  The capital of India is New Delhi.
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  Your name is Jeeya.

# %% [markdown]
# ### 3.5 Let's verify that the session data is isolated
#
# As mentioned earlier, a session is private conversation between an Agent and a User (i.e., two sessions do not share information). Let's run our `run_session` with a different session name `test-db-session-02` to confirm this.

# %%
await run_session(
    runner, ["Hello! What is my name?"], "test-db-session-02"
)  # Note, we are using new session name
# Out:
#  ### Session: test-db-session-02
#
# User > Hello! What is my name?
# gemini-2.5-flash-lite >  I do not have access to your personal information, so I do not know your name.

# %% [markdown]
# ### 3.6 How are the events stored in the Database?
#
# Since we are using a sqlite DB to store information, let's have a quick peek to see how information is stored.

# %%
import sqlite3

def check_data_in_db():
    with sqlite3.connect("my_agent_data.db") as connection:
        cursor = connection.cursor()
        result = cursor.execute(
            "select app_name, session_id, author, content from events"
        )
        print([_[0] for _ in result.description])
        for each in result.fetchall():
            print(each)


check_data_in_db()
# Out:
# ['app_name', 'session_id', 'author', 'content']
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'stateful-agentic-session', 'user', '{"parts": [{"text": "Hi, I am Jeeya! What is the capital of United States?"}], "role": "user"}')
# ('default', 'stateful-agentic-session', 'text_chat_bot', '{"parts": [{"text": "Hi Jeeya! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'stateful-agentic-session', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'stateful-agentic-session', 'text_chat_bot', '{"parts": [{"text": "Your name is Jeeya."}], "role": "model"}')
# ('default', 'stateful-agentic-session', 'user', '{"parts": [{"text": "What did I ask you about earlier?"}], "role": "user"}')
# ('default', 'stateful-agentic-session', 'text_chat_bot', '{"parts": [{"text": "You asked me about the capital of the United States."}], "role": "model"}')
# ('default', 'stateful-agentic-session', 'user', '{"parts": [{"text": "And remind me, what\'s my name?"}], "role": "user"}')
# ('default', 'stateful-agentic-session', 'text_chat_bot', '{"parts": [{"text": "Your name is Jeeya."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Sam! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hello Sam! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Sam."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hi, I am Jeeya! What is the capital of the United States?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Hi Jeeya! The capital of the United States is Washington, D.C."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Jeeya."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "What is the capital of India?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "The capital of India is New Delhi."}], "role": "model"}')
# ('default', 'test-db-session-01', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-01', 'text_chat_bot', '{"parts": [{"text": "Your name is Jeeya."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, so I do not know your name."}], "role": "model"}')
# ('default', 'test-db-session-02', 'user', '{"parts": [{"text": "Hello! What is my name?"}], "role": "user"}')
# ('default', 'test-db-session-02', 'text_chat_bot', '{"parts": [{"text": "I do not have access to your personal information, so I do not know your name."}], "role": "model"}')

# %% [markdown]
# ---
# ## ⏳ Section 4: Context Compaction
#
# As you can see, all the events are stored in full in the session Database, and this quickly adds up. For a long, complex task, this list of events can become very large, leading to slower performance and higher costs.
#
# But what if we could automatically summarize the past? Let's use ADK's **Context Compaction** feature to see **how to automatically reduce the context that's stored in the Session.**

# %% [markdown]
# <img src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day3/context-compaction.png" width="1400" alt="Context compaction">

# %% [markdown]
# ### 4.1 Create an App for the agent
#
# To enable this feature, let's use the same `chatbot_agent` we created in Section 3.2.
#
# The first step is to create an object called `App`. We'll give it a name and pass in our chatbot_agent.
#
# We'll also create a new config to do the Context Compaction. This **`EventsCompactionConfig`** defines two key variables:
#
# - **compaction_interval**: Asks the Runner to compact the history after every `n` conversations
# - **overlap_size**: Defines the number of previous conversations to retain for overlap
#
# We'll then provide this app to the Runner.

# %%
# Re-define our app with Events Compaction enabled
research_app_compacting = App(
    name="research_app_compacting",
    root_agent=chatbot_agent,
    # This is the new part!
    events_compaction_config=EventsCompactionConfig(
        compaction_interval=3,  # Trigger compaction every 3 invocations
        overlap_size=1,  # Keep 1 previous turn for context
    ),
)

db_url = "sqlite:///my_agent_data.db"  # Local SQLite file
session_service = DatabaseSessionService(db_url=db_url)

# Create a new runner for our upgraded app
research_runner_compacting = Runner(
    app=research_app_compacting, session_service=session_service
)


print("✅ Research App upgraded with Events Compaction!")
# Out:
# ✅ Research App upgraded with Events Compaction!
# /tmp/ipykernel_48/3773147741.py:6: UserWarning: [EXPERIMENTAL] EventsCompactionConfig: This feature is experimental and may change or be removed in future versions without notice. It may introduce breaking changes at any time.
#   events_compaction_config=EventsCompactionConfig(

# %% [markdown]
# ### 4.2 Running the Demo
#
# Now, let's have a conversation that is long enough to trigger the compaction. When you run the cell below, the output will look like a normal conversation. However, because we configured our `App`, a compaction process will run silently in the background after the 3rd invocation.
#
# In the next step, we'll prove that it happened.

# %%
# Turn 1
await run_session(
    research_runner_compacting,
    "What is the latest news about AI in healthcare?",
    "compaction_demo",
)

# Turn 2
await run_session(
    research_runner_compacting,
    "Are there any new developments in drug discovery?",
    "compaction_demo",
)

# Turn 3 - Compaction should trigger after this turn!
await run_session(
    research_runner_compacting,
    "Tell me more about the second development you found.",
    "compaction_demo",
)

# Turn 4
await run_session(
    research_runner_compacting,
    "Who are the main companies involved in that?",
    "compaction_demo",
)
# Out:
#  ### Session: compaction_demo
#
# User > What is the latest news about AI in healthcare?
# gemini-2.5-flash-lite >  Here's a summary of the latest news and trends in AI in healthcare, focusing on key areas of development and impact:
#
# **1. Advancements in Diagnostics and Imaging:**
#
# *   **AI-powered image analysis is becoming more sophisticated:** Algorithms are excelling at detecting subtle anomalies in X-rays, CT scans, MRIs, and pathology slides, often with accuracy comparable to or exceeding human experts. This is particularly impactful in areas like radiology, oncology, and ophthalmology.
# *   **Early disease detection:** AI is being used to identify early signs of diseases like Alzheimer's, Parkinson's, diabetic retinopathy, and certain cancers from medical images and even from wearable device data, potentially leading to earlier intervention and better outcomes.
# *   **Personalized treatment recommendations:** AI can analyze patient data, including genetic information and medical history, to predict how a patient might respond to different treatments, paving the way for more personalized and effective care.
#
# **2. Drug Discovery and Development Acceleration:**
#
# *   **AI is revolutionizing drug discovery:** Machine learning models can sift through vast datasets of biological and chemical information to identify potential drug candidates, predict their efficacy, and even design novel molecules, significantly speeding up the traditionally slow and expensive process.
# *   **Repurposing existing drugs:** AI can help identify new therapeutic uses for existing drugs, offering a faster and more cost-effective path to new treatments.
# *   **Clinical trial optimization:** AI is being used to improve patient recruitment for clinical trials, predict trial outcomes, and analyze trial data more efficiently.
#
# **3. Improving Operational Efficiency and Workflow:**
#
# *   **Administrative task automation:** AI-powered tools are automating mundane tasks like appointment scheduling, billing, medical coding, and prior authorization requests, freeing up healthcare professionals to focus on patient care.
# *   **Predictive analytics for resource management:** Hospitals are using AI to predict patient volumes, staffing needs, and equipment utilization, leading to more efficient resource allocation and reduced costs.
# *   **Streamlining electronic health records (EHRs):** AI can help extract relevant information from EHRs, summarize patient histories, and even assist with clinical documentation.
#
# **4. Enhanced Patient Care and Engagement:**
#
# *   **AI-powered chatbots and virtual assistants:** These tools are providing patients with 24/7 access to health information, answering FAQs, reminding them about appointments and medications, and even offering preliminary symptom assessment.
# *   **Remote patient monitoring:** AI analyzes data from wearable devices and remote sensors to track patients' health metrics, detect potential issues, and alert healthcare providers, enabling proactive interventions and reducing hospital readmissions.
# *   **Personalized health coaching:** AI can deliver tailored health advice and support to individuals, encouraging healthier behaviors and managing chronic conditions.
#
# **5. Ethical Considerations and Regulatory Landscape:**
#
# *   **Data privacy and security:** As AI relies heavily on patient data, ensuring its privacy and security remains a paramount concern. Robust data governance and cybersecurity measures are crucial.
# *   **Bias in AI algorithms:** Ensuring that AI algorithms are fair and equitable across different demographic groups is an ongoing challenge. Researchers are actively working to identify and mitigate biases.
# *   **Regulatory approval:** Regulatory bodies like the FDA are actively developing frameworks for the approval and oversight of AI-powered medical devices and software. The pace of innovation often outstrips regulatory processes.
# *   **Physician adoption and trust:** Building trust among healthcare professionals in AI tools and ensuring proper training for their use are essential for successful implementation.
#
# **Key Trends to Watch:**
#
# *   **Generative AI (like large language models):** Beyond chatbots, generative AI is showing promise in areas like medical writing, synthesizing research, and even creating synthetic patient data for training AI models.
# *   **Explainable AI (XAI):** As AI becomes more integrated into critical healthcare decisions, there's a growing demand for AI systems that can explain their reasoning, increasing transparency and trust.
# *   **Federated Learning:** This approach allows AI models to be trained on decentralized data sources (e.g., at individual hospitals) without sharing raw patient data, addressing privacy concerns.
# *   **AI-driven precision medicine:** The integration of AI with genomics, proteomics, and other omics data will lead to increasingly tailored diagnostic and therapeutic strategies.
#
# **In summary, AI in healthcare is no longer a futuristic concept; it's actively being implemented across various domains, promising to improve diagnostic accuracy, accelerate drug discovery, enhance operational efficiency, and personalize patient care. However, significant ethical, regulatory, and adoption challenges remain to be addressed for its full potential to be realized.**
#
#  ### Session: compaction_demo
#
# User > Are there any new developments in drug discovery?
# gemini-2.5-flash-lite >  Yes, there are **very significant and rapidly evolving new developments in drug discovery, largely driven by the advancements in AI and other cutting-edge technologies.** Here's a breakdown of some of the most exciting areas:
#
# **1. AI-Powered Drug Discovery is Exploding:**
#
# *   **Accelerated Target Identification:** AI algorithms can analyze vast amounts of biological data (genomics, proteomics, clinical data, scientific literature) to identify novel disease targets (specific genes, proteins, or pathways) that were previously unknown or difficult to find.
# *   **De Novo Drug Design:** This is a game-changer. Instead of just screening existing libraries, AI can now *design* novel drug molecules from scratch, optimizing them for specific properties like binding affinity, efficacy, and reduced toxicity. Generative AI models are particularly powerful here.
# *   **Predicting Drug Efficacy and Toxicity:** Machine learning models can predict how a potential drug candidate will perform *in silico* (on a computer) before costly lab experiments, saving time and resources. This includes predicting side effects and potential drug-drug interactions.
# *   **Optimizing Preclinical Studies:** AI can help select the most promising drug candidates for further testing, design more efficient preclinical experiments, and even predict the outcomes of these studies.
# *   **Repurposing Existing Drugs:** AI can sift through data to find new therapeutic uses for existing drugs, which is a much faster and cheaper route to market than developing entirely new compounds.
#
# **Examples of AI in Drug Discovery:**
#
# *   **Companies like Insilico Medicine, Recursion Pharmaceuticals, Atomwise, and BenevolentAI** are at the forefront, using AI to discover novel drug candidates for various diseases, including cancer, fibrosis, and neurodegenerative disorders.
# *   **Recent breakthroughs:** Several AI-discovered drugs are now entering or have entered clinical trials, demonstrating the tangible progress being made.
#
# **2. Advances in Synthetic Biology and Gene Editing:**
#
# *   **CRISPR-based Therapeutics:** While not strictly drug discovery, CRISPR and other gene-editing technologies are creating entirely new therapeutic modalities. AI is playing a role in designing more precise and efficient gene-editing tools.
# *   **Engineered Cells and Microbes:** Synthetic biology is being used to engineer cells or microbes to produce therapeutic molecules or even act as living drugs.
#
# **3. New Modalities Beyond Small Molecules and Antibodies:**
#
# *   **RNA-based Therapeutics:** mRNA vaccines (like those for COVID-19) have opened the door for other RNA-based therapies for a range of diseases, from cancer to genetic disorders.
# *   **Peptide Therapeutics:** Short chains of amino acids (peptides) are emerging as potent and specific therapeutic agents with improved safety profiles compared to some small molecules.
# *   **Oligonucleotide Therapeutics:** These are short, synthetic strands of DNA or RNA that can modulate gene expression, offering new ways to treat genetic diseases.
#
# **4. Enhanced High-Throughput Screening and Automation:**
#
# *   **Robotic automation:** Advanced robotics allows for the screening of millions of compounds much faster and more efficiently.
# *   **Organ-on-a-chip and 3D tissue models:** These sophisticated lab-grown models of human organs and tissues provide more accurate predictions of drug responses than traditional cell cultures, reducing the need for animal testing and improving the translation of preclinical results to humans.
#
# **5. Focus on Undruggable Targets:**
#
# *   Traditional drug discovery has struggled to target certain disease-causing proteins (e.g., those lacking well-defined binding pockets). New AI-driven approaches and novel chemical modalities are beginning to make these "undruggable" targets accessible.
#
# **Challenges and the Future:**
#
# Despite these incredible advances, challenges remain:
#
# *   **Validation:** AI-predicted drug candidates still need rigorous experimental validation.
# *   **Data Quality and Access:** The success of AI depends on high-quality, comprehensive, and accessible biological and chemical data.
# *   **Regulatory Hurdles:** Approving novel AI-discovered drugs requires careful scrutiny and established pathways.
# *   **Cost:** While AI can reduce some costs, the overall drug discovery and development process remains incredibly expensive.
#
# However, the trajectory is clear: **AI and these other technological leaps are fundamentally transforming drug discovery, making it faster, more efficient, and more likely to yield novel and effective treatments for a wider range of diseases.** We are likely to see an increasing number of drugs entering clinical trials and ultimately reaching patients that owe their existence to these new approaches.
#
#  ### Session: compaction_demo
#
# User > Tell me more about the second development you found.
# gemini-2.5-flash-lite >  You're asking about the second development I mentioned: **Advances in Synthetic Biology and Gene Editing**. This is a fascinating and rapidly growing area with profound implications for medicine.
#
# Let's break it down:
#
# **What are Synthetic Biology and Gene Editing?**
#
# *   **Synthetic Biology:** This field involves the design and construction of new biological parts, devices, and systems, or the re-design of existing, natural biological systems for useful purposes. Think of it like engineering biological components with the same precision we use to build electronics. This can involve modifying existing organisms or creating entirely new ones with specific functions.
# *   **Gene Editing:** This refers to technologies that allow scientists to make precise changes to the DNA of living organisms. The most famous example is **CRISPR-Cas9**, which acts like molecular scissors to cut DNA at specific locations, allowing for genes to be removed, added, or altered.
#
# **How are they impacting Drug Discovery and Therapeutics?**
#
# The impact is multifaceted, moving beyond traditional "drug" molecules to entirely new ways of treating diseases:
#
# 1.  **CRISPR-Based Therapeutics:**
#     *   **Correcting Genetic Defects:** The most direct application is to fix faulty genes that cause genetic diseases like cystic fibrosis, sickle cell anemia, Huntington's disease, and certain forms of blindness. For example, scientists are using CRISPR to edit the genes responsible for these conditions *in vivo* (directly in the body) or *ex vivo* (editing cells outside the body and then reintroducing them).
#     *   **Developing Cancer Immunotherapies:** CRISPR is being used to engineer a patient's own immune cells (like T-cells) to better recognize and attack cancer cells. This involves modifying genes to enhance their anti-cancer activity or remove "brakes" that prevent them from attacking.
#     *   **Creating Disease Models:** CRISPR is invaluable for creating precise animal or cell models of human diseases, which are essential for understanding disease mechanisms and testing potential new drugs and therapies.
#
# 2.  **Engineered Cells as Therapies (Cell Therapies):**
#     *   **CAR T-cell Therapy:** This is a prime example. T-cells are genetically modified using techniques (often involving viral vectors or other gene editing tools) to express Chimeric Antigen Receptors (CARs) that specifically target cancer cells. These engineered cells are then infused back into the patient to fight the cancer.
#     *   **Stem Cell Therapies:** Synthetic biology can be used to engineer stem cells for regenerative medicine, aiming to repair damaged tissues and organs.
#     *   **Microbial Therapies:** Scientists are engineering bacteria or other microbes to act as living drugs. These engineered microbes could deliver therapeutic agents to specific sites in the body, colonize tumors, or even produce therapeutic molecules.
#
# 3.  **Producing Therapeutic Molecules:**
#     *   **Bio-manufacturing:** Synthetic biology is used to engineer microorganisms (like yeast or bacteria) or plant cells to efficiently produce complex therapeutic proteins, antibodies, vaccines, or even difficult-to-synthesize small molecules that would be expensive or impossible to make through traditional chemical synthesis. This can lead to more cost-effective and sustainable production of existing and new medicines.
#
# **AI's Role in This Development:**
#
# You asked specifically about the second development, but it's crucial to see how AI is interwoven:
#
# *   **Designing CRISPR Components:** AI is helping to design more precise guide RNAs and Cas enzymes for CRISPR, improving its accuracy and reducing off-target effects.
# *   **Predicting Gene Editing Outcomes:** Machine learning can predict the efficiency and potential outcomes of gene editing in different cell types or organisms.
# *   **Engineering Biological Circuits:** Synthetic biology involves designing complex biological circuits. AI can assist in the design and optimization of these circuits.
# *   **Analyzing Large Biological Datasets:** Understanding the intricate workings of cells and genes requires analyzing massive datasets. AI is essential for making sense of this information to guide synthetic biology efforts.
#
# **Why is this Significant?**
#
# *   **Paradigm Shift:** It represents a shift from treating symptoms with chemical drugs to addressing the root cause of diseases at the genetic or cellular level.
# *   **Potentially Curative Therapies:** For many genetic and chronic diseases, these approaches offer the possibility of a one-time, curative treatment rather than lifelong management.
# *   **Novel Treatment Options:** They open up entirely new therapeutic avenues for diseases that were previously untreatable.
#
# **Challenges:**
#
# *   **Delivery:** Getting gene editing tools or engineered cells to the right cells in the body safely and effectively remains a major hurdle.
# *   **Safety and Off-Target Effects:** Ensuring gene editing is precise and doesn't cause unintended mutations is critical.
# *   **Immunogenicity:** The body's immune system can sometimes attack engineered cells or delivery vehicles.
# *   **Ethical Considerations:** As with any powerful technology, there are significant ethical debates surrounding germline editing (editing genes that can be passed to future generations) and equitable access to these advanced therapies.
#
# In essence, synthetic biology and gene editing are empowering us to become biological engineers, offering powerful new tools to combat disease by directly manipulating the building blocks of life.
#
#  ### Session: compaction_demo
#
# User > Who are the main companies involved in that?
# gemini-2.5-flash-lite >  The landscape of companies involved in synthetic biology and gene editing is vast and dynamic, encompassing both established pharmaceutical giants and innovative biotechnology startups. Here are some of the main players and categories of companies to consider:
#
# **1. Gene Editing Technology Developers (Platform Companies):**
#
# These companies are primarily focused on developing and licensing the core gene editing technologies (like CRISPR) and providing them as tools for others to use.
#
# *   **CRISPR Therapeutics:** A leading company focused on developing CRISPR-based gene-edited therapies for serious diseases. They have several products in clinical trials.
# *   **Editas Medicine:** Another major player in CRISPR gene editing, focusing on developing transformative genetic medicines.
# *   **Intellia Therapeutics:** A pioneer in developing CRISPR-based therapies, often partnering with larger companies.
# *   **Beam Therapeutics:** Focuses on **base editing** and **prime editing**, which are more precise forms of gene editing than traditional CRISPR-Cas9.
#
# **2. Biopharmaceutical Companies Developing Gene and Cell Therapies:**
#
# These companies are actively using gene editing and synthetic biology to develop therapeutic products for specific diseases. Many of these are also large pharmaceutical companies with dedicated R&D in this area.
#
# *   **Vertex Pharmaceuticals:** Known for its work in cystic fibrosis, they are also investing heavily in gene editing therapies for the disease.
# *   **Novartis:** A giant in the pharmaceutical industry, they have been a pioneer in cell therapies, particularly with their CAR T-cell therapy Kymriah.
# *   **Gilead Sciences:** Has a strong presence in cell therapy with its CAR T-cell products for blood cancers.
# *   **BioNTech:** While famous for mRNA vaccines, they are also exploring gene editing and cell therapies for various diseases, including cancer.
# *   **Moderna:** Similar to BioNTech, they are leveraging their mRNA platform and exploring applications in gene editing and other advanced therapeutic modalities.
# *   **Sanofi:** Actively involved in developing and acquiring cell and gene therapy capabilities.
# *   **Roche:** Investing in gene therapy and gene editing research, particularly in rare diseases and oncology.
# *   **Pfizer:** Engaging in gene therapy and gene editing through collaborations and acquisitions.
# *   **Bluebird Bio:** Focused on gene therapies for rare genetic diseases, often using viral vectors for delivery.
#
# **3. Synthetic Biology and Bio-manufacturing Companies:**
#
# These companies are focused on engineering organisms to produce useful products, including therapeutics, or on providing the tools and platforms for synthetic biology.
#
# *   **Ginkgo Bioworks:** A leading organism engineering company that designs custom microbes for a wide range of applications, including the production of pharmaceuticals, agricultural products, and industrial chemicals.
# *   **Amyris:** Utilizes synthetic biology to develop and produce a variety of molecules, including ingredients for consumer products and potentially therapeutics.
# *   **Zymergen (now part of Ginkgo Bioworks):** Was also a significant player in using synthetic biology to create novel materials and products.
#
# **4. Companies Focused on Delivery Systems:**
#
# A critical aspect of gene and cell therapy is efficiently and safely delivering the genetic material or cells to the target site. Many companies specialize in these delivery technologies.
#
# *   **Catalent:** A major contract development and manufacturing organization (CDMO) with significant expertise in producing viral vectors for gene therapies.
# *   **Lonza:** Another major CDMO providing manufacturing services for cell and gene therapies.
# *   **Thermo Fisher Scientific:** Offers a broad range of reagents, instruments, and services that support gene editing and cell therapy development and manufacturing.
# *   **Various startups focused on lipid nanoparticles (LNPs), adeno-associated viruses (AAVs), and other viral/non-viral delivery methods.**
#
# **5. Academic Spin-offs and Niche Players:**
#
# Many of the most innovative breakthroughs come from academic research, leading to the creation of specialized spin-off companies. There are also many smaller companies focusing on very specific niches within gene editing or synthetic biology.
#
# **Key Trends:**
#
# *   **Partnerships and Collaborations:** You'll see many collaborations between gene editing platform companies, drug developers, and CDMOs.
# *   **Acquisitions:** Larger pharmaceutical companies are actively acquiring smaller biotech firms with promising gene editing or cell therapy pipelines.
# *   **Focus on Rare Diseases:** Many of the initial applications of gene editing are in rare genetic disorders where the unmet need is high and the potential for impact is significant.
# *   **Expansion into Broader Diseases:** As the technology matures, it's being explored for more common diseases like cancer, cardiovascular disease, and neurological disorders.
#
# This is by no means an exhaustive list, as the field is constantly evolving with new players emerging and existing ones expanding their focus. However, these are some of the most prominent companies shaping the future of gene editing and synthetic biology in healthcare.

# %% [markdown]
# ### 4.3 Verifying Compaction in the Session History
#
# The conversation above looks normal, but the history has been changed behind the scenes. How can we prove it?
#
# We can inspect the `events` list from our session. The compaction process **doesn't delete old events; it replaces them with a single, new `Event` that contains the summary.** Let's find it.

# %%
# Get the final session state
final_session = await session_service.get_session(
    app_name=research_runner_compacting.app_name,
    user_id=USER_ID,
    session_id="compaction_demo",
)

print("--- Searching for Compaction Summary Event ---")
found_summary = False
for event in final_session.events:
    # Compaction events have a 'compaction' attribute
    if event.actions and event.actions.compaction:
        print("\n✅ SUCCESS! Found the Compaction Event:")
        print(f"  Author: {event.author}")
        print(f"\n Compacted information: {event}")
        found_summary = True
        break

if not found_summary:
    print(
        "\n❌ No compaction event found. Try increasing the number of turns in the demo."
    )
# Out:
# --- Searching for Compaction Summary Event ---
#
# ✅ SUCCESS! Found the Compaction Event:
#   Author: user
#
#  Compacted information: model_version=None content=None grounding_metadata=None partial=None turn_complete=None finish_reason=None error_code=None error_message=None interrupted=None custom_metadata=None usage_metadata=None live_session_resumption_update=None input_transcription=None output_transcription=None avg_logprobs=None logprobs_result=None cache_metadata=None citation_metadata=None invocation_id='f6a114c1-416b-4901-911f-0217ec853119' author='user' actions=EventActions(skip_summarization=None, state_delta={}, artifact_delta={}, transfer_to_agent=None, escalate=None, requested_auth_configs={}, requested_tool_confirmations={}, compaction={'start_timestamp': 1762949710.925237, 'end_timestamp': 1762949720.521555, 'compacted_content': {'parts': [{'function_call': None, 'code_execution_result': None, 'executable_code': None, 'file_data': None, 'function_response': None, 'inline_data': None, 'text': 'The user inquired about new developments in drug discovery. The AI agent provided an overview of advancements, highlighting AI\'s exploding role in target identification, *de novo* drug design, predicting efficacy/toxicity, optimizing preclinical studies, and drug repurposing. The agent also mentioned advancements in synthetic biology and gene editing, new therapeutic modalities like RNA-based and peptide therapeutics, enhanced high-throughput screening, and a focus on previously "undruggable" targets.\n\nThe user then asked for more details about the second development mentioned, which was **Advances in Synthetic Biology and Gene Editing**. The AI agent explained that synthetic biology involves designing and constructing new biological systems, while gene editing (like CRISPR-Cas9) allows for precise DNA modifications.\n\nThe agent detailed the impact of these technologies on drug discovery and therapeutics:\n\n*   **CRISPR-Based Therapeutics:** Used to correct genetic defects, develop cancer immunotherapies, and create disease models.\n*   **Engineered Cells as Therapies:** Including CAR T-cell therapy and engineered microbes for therapeutic delivery.\n*   **Producing Therapeutic Molecules:** Using engineered organisms for bio-manufacturing of complex proteins, antibodies, and vaccines.\n\nCrucially, the AI agent emphasized the **interwoven role of AI** in this development, assisting in designing CRISPR components, predicting gene editing outcomes, engineering biological circuits, and analyzing large biological datasets.\n\nThe significance of synthetic biology and gene editing was highlighted as a paradigm shift towards addressing root causes of disease, offering potentially curative therapies and novel treatment options. However, challenges such as delivery, safety (off-target effects), immunogenicity, and ethical considerations were also discussed.', 'thought': None, 'thought_signature': None, 'video_metadata': None}], 'role': 'model'}}, end_of_agent=None, agent_state=None, rewind_before_invocation_id=None) long_running_tool_ids=set() branch=None id='e7d91cad-bee8-446f-9f72-5afbcca0a44a' timestamp=1762949729.53496

# %% [markdown]
# ### 4.4 What you've accomplished: Automatic Context Management
#
# You just found the proof! The presence of that special summary `Event` in your session's history is the tangible result of the compaction process.
#
# **Let's recap what you just witnessed:**
#
# 1.  **Silent Operation**: You ran a standard conversation, and from the outside, nothing seemed different.
# 2.  **Background Compaction**: Because you configured the `App` with `EventsCompactionConfig`, the ADK `Runner` automatically monitored the conversation length. Once the threshold was met, it triggered the summarization process in the background.
# 3.  **Verified Result**: By inspecting the session's events, you found the summary that the LLM generated. This summary now replaces the older, more verbose turns in the agent's active context.
#
# **For all future turns in this conversation, the agent will be given this concise summary instead of the full history.** This saves costs, improves performance, and helps the agent stay focused on what's most important.

# %% [markdown]
# ### 4.5 More Context Engineering options in ADK
#
# #### 👉 Custom Compaction
# In this example, we used ADK's default summarizer. For more advanced use cases, you can provide your own by defining a custom `SlidingWindowCompactor` and passing it to the config. This allows you to control the summarization prompt or even use a different, specialized LLM for the task. You can read more about it in the [official documentation](https://google.github.io/adk-docs/context/compaction/).
#
# #### 👉 Context Caching
# ADK also provides **Context Caching** to help reduce the token size of the static instructions that are fed to the LLM by caching the request data. Read more about it [here](https://google.github.io/adk-docs/context/caching/).

# %% [markdown]
# ### The Problem
#
# While we can do Context Compaction and use a database to resume a session, we face new challenges now. In some cases, **we have key information or preferences that we want to share across other sessions.**
#
# In these scenarios, instead of sharing the entire session history, transferring information from a few key variables can improve the session experience. Let's see how to do it!

# %% [markdown]
# ---
# ## 🤝 Section 5: Working with Session State
#
# ### 5.1 Creating custom tools for Session state management
#
# Let's explore how to manually manage session state through custom tools. In this example, we'll identify a **transferable characteristic**, like a user's name and their country, and create tools to capture and save it.
#
# **Why This Example?**
#
# The username is a perfect example of information that:
#
# - Is introduced once but referenced multiple times
# - Should persist throughout a conversation
# - Represents a user-specific characteristic that enhances personalization
#
# Here, for demo purposes, we'll create two tools that can store and retrieve user name and country from the Session State. **Note that all tools have access to the `ToolContext` object.** You don't have to create separate tools for each piece of information you want to share.

# %%
# Define scope levels for state keys (following best practices)
USER_NAME_SCOPE_LEVELS = ("temp", "user", "app")


# This demonstrates how tools can write to session state using tool_context.
# The 'user:' prefix indicates this is user-specific data.
def save_userinfo(
    tool_context: ToolContext, user_name: str, country: str
) -> Dict[str, Any]:
    """
    Tool to record and save user name and country in session state.

    Args:
        user_name: The username to store in session state
        country: The name of the user's country
    """
    # Write to session state using the 'user:' prefix for user data
    tool_context.state["user:name"] = user_name
    tool_context.state["user:country"] = country

    return {"status": "success"}


# This demonstrates how tools can read from session state.
def retrieve_userinfo(tool_context: ToolContext) -> Dict[str, Any]:
    """
    Tool to retrieve user name and country from session state.
    """
    # Read from session state
    user_name = tool_context.state.get("user:name", "Username not found")
    country = tool_context.state.get("user:country", "Country not found")

    return {"status": "success", "user_name": user_name, "country": country}


print("✅ Tools created.")
# Out:
# ✅ Tools created.

# %% [markdown]
# **Key Concepts:**
# - Tools can access `tool_context.state` to read/write session state
# - Use descriptive key prefixes (`user:`, `app:`, `temp:`) for organization
# - State persists across conversation turns within the same session

# %% [markdown]
# ### 5.2 Creating an Agent with Session State Tools
#
# Now let's create a new agent that has access to our session state management tools:

# %%
# Configuration
APP_NAME = "default"
USER_ID = "default"
MODEL_NAME = "gemini-2.5-flash-lite"

# Create an agent with session state tools
root_agent = LlmAgent(
    model=Gemini(model="gemini-2.5-flash-lite", retry_options=retry_config),
    name="text_chat_bot",
    description="""A text chatbot.
    Tools for managing user context:
    * To record username and country when provided use `save_userinfo` tool. 
    * To fetch username and country when required use `retrieve_userinfo` tool.
    """,
    tools=[save_userinfo, retrieve_userinfo],  # Provide the tools to the agent
)

# Set up session service and runner
session_service = InMemorySessionService()
runner = Runner(agent=root_agent, session_service=session_service, app_name="default")

print("✅ Agent with session state tools initialized!")
# Out:
# ✅ Agent with session state tools initialized!

# %% [markdown]
# ### 5.3 Testing Session State in Action
#
# Let's test how the agent uses session state to remember information across conversation turns:

# %%
# Test conversation demonstrating session state
await run_session(
    runner,
    [
        "Hi there, how are you doing today? What is my name?",  # Agent shouldn't know the name yet
        "My name is Jeeya. I'm from INDIA.",  # Provide name - agent should save it
        "What is my name? Which country am I from?",  # Agent should recall from session state
    ],
    "state-demo-session",
)
# Out:
#  ### Session: state-demo-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing great. I'd love to tell you your name, but I don't have access to that information. I also don't have access to any personally identifiable information unless you provide it.
#
#
# User > My name is Jeeya. I'm from INDIA.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Hi Jeeya from INDIA, it is a pleasure to meet you! I will save this information.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  It is a pleasure to meet you, Jeeya from INDIA! I've saved your information.
#
# User > What is my name? Which country am I from?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# gemini-2.5-flash-lite >  Your name is Jeeya and you are from INDIA.

# %% [markdown]
# ### 5.4 Inspecting Session State
#
# Let's directly inspect the session state to see what's stored:

# %%
# Retrieve the session and inspect its state
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="state-demo-session"
)

print("Session State Contents:")
print(session.state)
print("\n🔍 Notice the 'user:name' and 'user:country' keys storing our data!")
# Out:
# Session State Contents:
# {'user:name': 'Jeeya', 'user:country': 'INDIA'}
#
# 🔍 Notice the 'user:name' and 'user:country' keys storing our data!

# %% [markdown]
# ### 5.5 Session State Isolation
#
# As we've already seen, an important characteristic of session state is that it's isolated per session. Let's demonstrate this by starting a new session:

# %%
# Start a completely new session - the agent won't know our name
await run_session(
    runner,
    ["Hi there, how are you doing today? What is my name?"],
    "new-isolated-session",
)

# Expected: The agent won't know the name because this is a different session
# Out:
#  ### Session: new-isolated-session
#
# User > Hi there, how are you doing today? What is my name?
# gemini-2.5-flash-lite >  Hello! I'm doing well, thank you for asking. I can't remember your name right now. Would you mind telling me what it is?

# %% [markdown]
# ### 5.6 Cross-Session State Sharing
#
# While sessions are isolated by default, you might notice something interesting. Let's check the state of our new session (`new-isolated-session`):

# %%
# Check the state of the new session
session = await session_service.get_session(
    app_name=APP_NAME, user_id=USER_ID, session_id="new-isolated-session"
)

print("New Session State:")
print(session.state)

# Note: Depending on implementation, you might see shared state here.
# This is where the distinction between session-specific and user-specific state becomes important.
# Out:
# New Session State:
# {'user:name': 'Jeeya', 'user:country': 'INDIA'}

# %% [markdown]
# ---
#
# ## 🧹 Cleanup

# %%
# Clean up any existing database to start fresh (if Notebook is restarted)
import os

if os.path.exists("my_agent_data.db"):
    os.remove("my_agent_data.db")
print("✅ Cleaned up old database files")
# Out:
# ✅ Cleaned up old database files

# %% [markdown]
# ---
# ## 📊 Summary
#
# 🎉 Congratulations! You've learned the fundamentals of building stateful AI agents:
#
# - ✅ **Context Engineering** - You understand how to assemble context for LLMs using Context Compaction
# - ✅ **Sessions & Events** - You can maintain conversation history across multiple turns
# - ✅ **Persistent Storage** - You know how to make conversations survive restarts
# - ✅ **Session State** - You can track structured data during conversations
# - ✅ **Manual State Management** - You've experienced both the power and limitations of manual approaches
# - ✅ **Production Considerations** - You're ready to handle real-world challenges

# %% [markdown]
# ---
#
# ## ✅ Congratulations! You did it 🎉
#
# **ℹ️ Note: No submission required!**
#
# This notebook is for your hands-on practice and learning only. You **do not** need to submit it anywhere to complete the course.
#
# ### 📚 Learn More
#
# Refer to the following documentation to learn more:
#
# - [ADK Documentation](https://google.github.io/adk-docs/)
# - [ADK Sessions](https://google.github.io/adk-docs/)
# - [ADK Session-State](https://medium.com/google-cloud/2-minute-adk-manage-context-efficiently-with-artifacts-6fcc6683d274)
# - [ADK Session Compaction](https://google.github.io/adk-docs/context/compaction/#define-compactor)
#
# ### 🎯 Next Steps - Long Term Memory Systems (Part 2)
#
# #### Why do we need memory?
# In this notebook, we manually identified a couple characteristic (username and country) and built tools to manage it. But real conversations involve hundreds of such characteristics:
# - User preferences and habits
# - Past interactions and their outcomes
# - Domain knowledge and expertise levels
# - Communication styles and patterns
# - Contextual relationships between topics
#
# **The Memory System in ADK automates this entire process**, making it a valuable asset for building truly Context-Aware Agents that can accommodate any user's current and future needs.
#
# In the next notebook (Part 2: Memory Management), you'll learn how to:
# - Enable automatic memory extraction from conversations
# - Build agents that learn and adapt over time
# - Create truly personalized experiences at scale
# - Manage long-term knowledge across sessions
#
# Ready to transform your manual state management into an intelligent, automated Memory system? Let's continue to Part 2!

# %% [markdown]
# ---
#
# | Authors |
# | --- |
# | [Sampath M](https://www.linkedin.com/in/msampathkumar/) |
